# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

print(tf.__version__)
# Out:
# 2.6.0

# %%
NUM_WORDS = 1000

(train_data, train_labels), (test_data, test_labels) = keras.datasets.imdb.load_data(num_words=NUM_WORDS)

def multi_hot_sequences(sequences, dimension):
    # 0으로 채워진 (len(sequences), dimension) 크기의 행렬을 만듭니다
    results = np.zeros((len(sequences), dimension))
    for i, word_indices in enumerate(sequences):
        results[i, word_indices] = 1.0  # results[i]의 특정 인덱스만 1로 설정합니다
    return results


train_data = multi_hot_sequences(train_data, dimension=NUM_WORDS)
test_data = multi_hot_sequences(test_data, dimension=NUM_WORDS)

# %%
plt.plot(train_data[0])

# %%
baseline_model = keras.Sequential([
    # `.summary` 메서드 때문에 `input_shape`가 필요합니다
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

baseline_model.compile(optimizer='adam',
                       loss='binary_crossentropy',
                       metrics=['accuracy', 'binary_crossentropy'])

baseline_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 16)                16016
# _________________________________________________________________
# dense_1 (Dense)              (None, 16)                272
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 17
# =================================================================
# Total params: 16,305
# Trainable params: 16,305
# Non-trainable params: 0
# _________________________________________________________________

# %%
baseline_history = baseline_model.fit(train_data,
                                      train_labels,
                                      epochs=20,
                                      batch_size=512,
                                      validation_data=(test_data, test_labels),
                                      verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 2s - loss: 0.6210 - accuracy: 0.6802 - binary_crossentropy: 0.6210 - val_loss: 0.4876 - val_accuracy: 0.8024 - val_binary_crossentropy: 0.4876
# Epoch 2/20
# 49/49 - 0s - loss: 0.3988 - accuracy: 0.8361 - binary_crossentropy: 0.3988 - val_loss: 0.3573 - val_accuracy: 0.8505 - val_binary_crossentropy: 0.3573
# Epoch 3/20
# 49/49 - 0s - loss: 0.3297 - accuracy: 0.8654 - binary_crossentropy: 0.3297 - val_loss: 0.3341 - val_accuracy: 0.8600 - val_binary_crossentropy: 0.3341
# Epoch 4/20
# 49/49 - 0s - loss: 0.3111 - accuracy: 0.8709 - binary_crossentropy: 0.3111 - val_loss: 0.3284 - val_accuracy: 0.8609 - val_binary_crossentropy: 0.3284
# Epoch 5/20
# 49/49 - 0s - loss: 0.3039 - accuracy: 0.8748 - binary_crossentropy: 0.3039 - val_loss: 0.3309 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3309
# Epoch 6/20
# 49/49 - 0s - loss: 0.2987 - accuracy: 0.8764 - binary_crossentropy: 0.2987 - val_loss: 0.3271 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3271
# Epoch 7/20
# 49/49 - 0s - loss: 0.2963 - accuracy: 0.8772 - binary_crossentropy: 0.2963 - val_loss: 0.3273 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3273
# Epoch 8/20
# 49/49 - 0s - loss: 0.2939 - accuracy: 0.8780 - binary_crossentropy: 0.2939 - val_loss: 0.3268 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3268
# Epoch 9/20
# 49/49 - 0s - loss: 0.2908 - accuracy: 0.8805 - binary_crossentropy: 0.2908 - val_loss: 0.3280 - val_accuracy: 0.8597 - val_binary_crossentropy: 0.3280
# Epoch 10/20
# 49/49 - 0s - loss: 0.2887 - accuracy: 0.8794 - binary_crossentropy: 0.2887 - val_loss: 0.3304 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3304
# Epoch 11/20
# 49/49 - 0s - loss: 0.2829 - accuracy: 0.8822 - binary_crossentropy: 0.2829 - val_loss: 0.3337 - val_accuracy: 0.8566 - val_binary_crossentropy: 0.3337
# Epoch 12/20
# 49/49 - 0s - loss: 0.2805 - accuracy: 0.8836 - binary_crossentropy: 0.2805 - val_loss: 0.3313 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3313
# Epoch 13/20
# 49/49 - 0s - loss: 0.2743 - accuracy: 0.8867 - binary_crossentropy: 0.2743 - val_loss: 0.3313 - val_accuracy: 0.8578 - val_binary_crossentropy: 0.3313
# Epoch 14/20
# 49/49 - 0s - loss: 0.2700 - accuracy: 0.8884 - binary_crossentropy: 0.2700 - val_loss: 0.3342 - val_accuracy: 0.8571 - val_binary_crossentropy: 0.3342
# Epoch 15/20
# 49/49 - 0s - loss: 0.2645 - accuracy: 0.8914 - binary_crossentropy: 0.2645 - val_loss: 0.3370 - val_accuracy: 0.8562 - val_binary_crossentropy: 0.3370
# Epoch 16/20
# 49/49 - 0s - loss: 0.2573 - accuracy: 0.8952 - binary_crossentropy: 0.2573 - val_loss: 0.3415 - val_accuracy: 0.8568 - val_binary_crossentropy: 0.3415
# Epoch 17/20
# 49/49 - 0s - loss: 0.2510 - accuracy: 0.8966 - binary_crossentropy: 0.2510 - val_loss: 0.3467 - val_accuracy: 0.8550 - val_binary_crossentropy: 0.3467
# Epoch 18/20
# 49/49 - 0s - loss: 0.2440 - accuracy: 0.8999 - binary_crossentropy: 0.2440 - val_loss: 0.3516 - val_accuracy: 0.8522 - val_binary_crossentropy: 0.3516
# Epoch 19/20
# 49/49 - 0s - loss: 0.2330 - accuracy: 0.9064 - binary_crossentropy: 0.2330 - val_loss: 0.3529 - val_accuracy: 0.8537 - val_binary_crossentropy: 0.3529
# Epoch 20/20
# 49/49 - 0s - loss: 0.2259 - accuracy: 0.9100 - binary_crossentropy: 0.2259 - val_loss: 0.3627 - val_accuracy: 0.8502 - val_binary_crossentropy: 0.3627

# %%
smaller_model = keras.Sequential([
    keras.layers.Dense(4, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(4, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

smaller_model.compile(optimizer='adam',
                      loss='binary_crossentropy',
                      metrics=['accuracy', 'binary_crossentropy'])

smaller_model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 4)                 4004
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 20
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 5
# =================================================================
# Total params: 4,029
# Trainable params: 4,029
# Non-trainable params: 0
# _________________________________________________________________

# %%
smaller_history = smaller_model.fit(train_data,
                                    train_labels,
                                    epochs=20,
                                    batch_size=512,
                                    validation_data=(test_data, test_labels),
                                    verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6590 - accuracy: 0.6365 - binary_crossentropy: 0.6590 - val_loss: 0.6135 - val_accuracy: 0.7366 - val_binary_crossentropy: 0.6135
# Epoch 2/20
# 49/49 - 0s - loss: 0.5615 - accuracy: 0.7823 - binary_crossentropy: 0.5615 - val_loss: 0.5129 - val_accuracy: 0.8141 - val_binary_crossentropy: 0.5129
# Epoch 3/20
# 49/49 - 0s - loss: 0.4602 - accuracy: 0.8356 - binary_crossentropy: 0.4602 - val_loss: 0.4221 - val_accuracy: 0.8450 - val_binary_crossentropy: 0.4221
# Epoch 4/20
# 49/49 - 0s - loss: 0.3832 - accuracy: 0.8594 - binary_crossentropy: 0.3832 - val_loss: 0.3700 - val_accuracy: 0.8558 - val_binary_crossentropy: 0.3700
# Epoch 5/20
# 49/49 - 0s - loss: 0.3433 - accuracy: 0.8680 - binary_crossentropy: 0.3433 - val_loss: 0.3469 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3469
# Epoch 6/20
# 49/49 - 0s - loss: 0.3240 - accuracy: 0.8725 - binary_crossentropy: 0.3240 - val_loss: 0.3366 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3366
# Epoch 7/20
# 49/49 - 0s - loss: 0.3132 - accuracy: 0.8743 - binary_crossentropy: 0.3132 - val_loss: 0.3335 - val_accuracy: 0.8602 - val_binary_crossentropy: 0.3335
# Epoch 8/20
# 49/49 - 0s - loss: 0.3076 - accuracy: 0.8755 - binary_crossentropy: 0.3076 - val_loss: 0.3288 - val_accuracy: 0.8613 - val_binary_crossentropy: 0.3288
# Epoch 9/20
# 49/49 - 0s - loss: 0.3037 - accuracy: 0.8766 - binary_crossentropy: 0.3037 - val_loss: 0.3288 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3288
# Epoch 10/20
# 49/49 - 0s - loss: 0.3012 - accuracy: 0.8774 - binary_crossentropy: 0.3012 - val_loss: 0.3287 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3287
# Epoch 11/20
# 49/49 - 0s - loss: 0.2990 - accuracy: 0.8769 - binary_crossentropy: 0.2990 - val_loss: 0.3288 - val_accuracy: 0.8601 - val_binary_crossentropy: 0.3288
# Epoch 12/20
# 49/49 - 0s - loss: 0.2983 - accuracy: 0.8778 - binary_crossentropy: 0.2983 - val_loss: 0.3295 - val_accuracy: 0.8595 - val_binary_crossentropy: 0.3295
# Epoch 13/20
# 49/49 - 0s - loss: 0.2973 - accuracy: 0.8791 - binary_crossentropy: 0.2973 - val_loss: 0.3303 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3303
# Epoch 14/20
# 49/49 - 0s - loss: 0.2949 - accuracy: 0.8796 - binary_crossentropy: 0.2949 - val_loss: 0.3311 - val_accuracy: 0.8589 - val_binary_crossentropy: 0.3311
# Epoch 15/20
# 49/49 - 0s - loss: 0.2952 - accuracy: 0.8792 - binary_crossentropy: 0.2952 - val_loss: 0.3319 - val_accuracy: 0.8587 - val_binary_crossentropy: 0.3319
# Epoch 16/20
# 49/49 - 0s - loss: 0.2913 - accuracy: 0.8818 - binary_crossentropy: 0.2913 - val_loss: 0.3334 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3334
# Epoch 17/20
# 49/49 - 0s - loss: 0.2897 - accuracy: 0.8822 - binary_crossentropy: 0.2897 - val_loss: 0.3331 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3331
# Epoch 18/20
# 49/49 - 0s - loss: 0.2877 - accuracy: 0.8822 - binary_crossentropy: 0.2877 - val_loss: 0.3347 - val_accuracy: 0.8576 - val_binary_crossentropy: 0.3347
# Epoch 19/20
# 49/49 - 0s - loss: 0.2860 - accuracy: 0.8840 - binary_crossentropy: 0.2860 - val_loss: 0.3340 - val_accuracy: 0.8579 - val_binary_crossentropy: 0.3340
# Epoch 20/20
# 49/49 - 0s - loss: 0.2837 - accuracy: 0.8850 - binary_crossentropy: 0.2837 - val_loss: 0.3348 - val_accuracy: 0.8574 - val_binary_crossentropy: 0.3348

# %%
bigger_model = keras.models.Sequential([
    keras.layers.Dense(512, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(512, activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

bigger_model.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy','binary_crossentropy'])

bigger_model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 512)               512512
# _________________________________________________________________
# dense_7 (Dense)              (None, 512)               262656
# _________________________________________________________________
# dense_8 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 775,681
# Trainable params: 775,681
# Non-trainable params: 0
# _________________________________________________________________

# %%
bigger_history = bigger_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.4377 - accuracy: 0.7917 - binary_crossentropy: 0.4377 - val_loss: 0.3489 - val_accuracy: 0.8494 - val_binary_crossentropy: 0.3489
# Epoch 2/20
# 49/49 - 0s - loss: 0.2941 - accuracy: 0.8784 - binary_crossentropy: 0.2941 - val_loss: 0.3284 - val_accuracy: 0.8571 - val_binary_crossentropy: 0.3284
# Epoch 3/20
# 49/49 - 0s - loss: 0.2271 - accuracy: 0.9098 - binary_crossentropy: 0.2271 - val_loss: 0.3425 - val_accuracy: 0.8519 - val_binary_crossentropy: 0.3425
# Epoch 4/20
# 49/49 - 0s - loss: 0.1125 - accuracy: 0.9643 - binary_crossentropy: 0.1125 - val_loss: 0.4441 - val_accuracy: 0.8424 - val_binary_crossentropy: 0.4441
# Epoch 5/20
# 49/49 - 0s - loss: 0.0250 - accuracy: 0.9960 - binary_crossentropy: 0.0250 - val_loss: 0.5287 - val_accuracy: 0.8499 - val_binary_crossentropy: 0.5287
# Epoch 6/20
# 49/49 - 0s - loss: 0.0053 - accuracy: 0.9997 - binary_crossentropy: 0.0053 - val_loss: 0.6134 - val_accuracy: 0.8523 - val_binary_crossentropy: 0.6134
# Epoch 7/20
# 49/49 - 0s - loss: 0.0016 - accuracy: 0.9999 - binary_crossentropy: 0.0016 - val_loss: 0.6709 - val_accuracy: 0.8531 - val_binary_crossentropy: 0.6709
# Epoch 8/20
# 49/49 - 0s - loss: 0.0012 - accuracy: 1.0000 - binary_crossentropy: 0.0012 - val_loss: 0.7044 - val_accuracy: 0.8503 - val_binary_crossentropy: 0.7044
# Epoch 9/20
# 49/49 - 0s - loss: 5.3740e-04 - accuracy: 1.0000 - binary_crossentropy: 5.3740e-04 - val_loss: 0.7147 - val_accuracy: 0.8536 - val_binary_crossentropy: 0.7147
# Epoch 10/20
# 49/49 - 0s - loss: 3.5065e-04 - accuracy: 1.0000 - binary_crossentropy: 3.5065e-04 - val_loss: 0.7366 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.7366
# Epoch 11/20
# 49/49 - 0s - loss: 2.7075e-04 - accuracy: 1.0000 - binary_crossentropy: 2.7075e-04 - val_loss: 0.7539 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.7539
# Epoch 12/20
# 49/49 - 0s - loss: 2.1901e-04 - accuracy: 1.0000 - binary_crossentropy: 2.1901e-04 - val_loss: 0.7687 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.7687
# Epoch 13/20
# 49/49 - 0s - loss: 1.8228e-04 - accuracy: 1.0000 - binary_crossentropy: 1.8228e-04 - val_loss: 0.7817 - val_accuracy: 0.8535 - val_binary_crossentropy: 0.7817
# Epoch 14/20
# 49/49 - 0s - loss: 1.5386e-04 - accuracy: 1.0000 - binary_crossentropy: 1.5386e-04 - val_loss: 0.7934 - val_accuracy: 0.8531 - val_binary_crossentropy: 0.7934
# Epoch 15/20
# 49/49 - 0s - loss: 1.3201e-04 - accuracy: 1.0000 - binary_crossentropy: 1.3201e-04 - val_loss: 0.8045 - val_accuracy: 0.8536 - val_binary_crossentropy: 0.8045
# Epoch 16/20
# 49/49 - 0s - loss: 1.1413e-04 - accuracy: 1.0000 - binary_crossentropy: 1.1413e-04 - val_loss: 0.8149 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.8149
# Epoch 17/20
# 49/49 - 0s - loss: 9.9449e-05 - accuracy: 1.0000 - binary_crossentropy: 9.9449e-05 - val_loss: 0.8248 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.8248
# Epoch 18/20
# 49/49 - 0s - loss: 8.7499e-05 - accuracy: 1.0000 - binary_crossentropy: 8.7499e-05 - val_loss: 0.8337 - val_accuracy: 0.8536 - val_binary_crossentropy: 0.8337
# Epoch 19/20
# 49/49 - 0s - loss: 7.7430e-05 - accuracy: 1.0000 - binary_crossentropy: 7.7430e-05 - val_loss: 0.8427 - val_accuracy: 0.8534 - val_binary_crossentropy: 0.8427
# Epoch 20/20
# 49/49 - 0s - loss: 6.8980e-05 - accuracy: 1.0000 - binary_crossentropy: 6.8980e-05 - val_loss: 0.8510 - val_accuracy: 0.8535 - val_binary_crossentropy: 0.8510

# %%
def plot_history(histories, key='binary_crossentropy'):
  plt.figure(figsize=(16,10))

  for name, history in histories:
    val = plt.plot(history.epoch, history.history['val_'+key],
                   '--', label=name.title()+' Val')
    plt.plot(history.epoch, history.history[key], color=val[0].get_color(),
             label=name.title()+' Train')

  plt.xlabel('Epochs')
  plt.ylabel(key.replace('_',' ').title())
  plt.legend()

  plt.xlim([0,max(history.epoch)])


plot_history([('baseline', baseline_history),
              ('smaller', smaller_history),
              ('bigger', bigger_history)])

# %%
l2_model = keras.models.Sequential([
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dense(16, kernel_regularizer=keras.regularizers.l2(0.001),
                       activation='relu'),
    keras.layers.Dense(1, activation='sigmoid')
])

l2_model.compile(optimizer='adam',
                 loss='binary_crossentropy',
                 metrics=['accuracy', 'binary_crossentropy'])

l2_model_history = l2_model.fit(train_data, train_labels,
                                epochs=20,
                                batch_size=512,
                                validation_data=(test_data, test_labels),
                                verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.5913 - accuracy: 0.7346 - binary_crossentropy: 0.5443 - val_loss: 0.4499 - val_accuracy: 0.8328 - val_binary_crossentropy: 0.4032
# Epoch 2/20
# 49/49 - 0s - loss: 0.4033 - accuracy: 0.8519 - binary_crossentropy: 0.3565 - val_loss: 0.3861 - val_accuracy: 0.8562 - val_binary_crossentropy: 0.3398
# Epoch 3/20
# 49/49 - 0s - loss: 0.3668 - accuracy: 0.8671 - binary_crossentropy: 0.3213 - val_loss: 0.3797 - val_accuracy: 0.8570 - val_binary_crossentropy: 0.3352
# Epoch 4/20
# 49/49 - 0s - loss: 0.3555 - accuracy: 0.8710 - binary_crossentropy: 0.3118 - val_loss: 0.3764 - val_accuracy: 0.8582 - val_binary_crossentropy: 0.3338
# Epoch 5/20
# 49/49 - 0s - loss: 0.3498 - accuracy: 0.8729 - binary_crossentropy: 0.3080 - val_loss: 0.3678 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3269
# Epoch 6/20
# 49/49 - 0s - loss: 0.3433 - accuracy: 0.8749 - binary_crossentropy: 0.3032 - val_loss: 0.3671 - val_accuracy: 0.8608 - val_binary_crossentropy: 0.3279
# Epoch 7/20
# 49/49 - 0s - loss: 0.3414 - accuracy: 0.8751 - binary_crossentropy: 0.3031 - val_loss: 0.3668 - val_accuracy: 0.8595 - val_binary_crossentropy: 0.3292
# Epoch 8/20
# 49/49 - 0s - loss: 0.3402 - accuracy: 0.8746 - binary_crossentropy: 0.3033 - val_loss: 0.3663 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3302
# Epoch 9/20
# 49/49 - 0s - loss: 0.3370 - accuracy: 0.8764 - binary_crossentropy: 0.3015 - val_loss: 0.3642 - val_accuracy: 0.8584 - val_binary_crossentropy: 0.3294
# Epoch 10/20
# 49/49 - 0s - loss: 0.3368 - accuracy: 0.8749 - binary_crossentropy: 0.3025 - val_loss: 0.3685 - val_accuracy: 0.8565 - val_binary_crossentropy: 0.3348
# Epoch 11/20
# 49/49 - 0s - loss: 0.3348 - accuracy: 0.8751 - binary_crossentropy: 0.3015 - val_loss: 0.3616 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3289
# Epoch 12/20
# 49/49 - 0s - loss: 0.3310 - accuracy: 0.8766 - binary_crossentropy: 0.2987 - val_loss: 0.3597 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3278
# Epoch 13/20
# 49/49 - 0s - loss: 0.3310 - accuracy: 0.8754 - binary_crossentropy: 0.2994 - val_loss: 0.3579 - val_accuracy: 0.8595 - val_binary_crossentropy: 0.3268
# Epoch 14/20
# 49/49 - 0s - loss: 0.3270 - accuracy: 0.8765 - binary_crossentropy: 0.2962 - val_loss: 0.3568 - val_accuracy: 0.8596 - val_binary_crossentropy: 0.3264
# Epoch 15/20
# 49/49 - 0s - loss: 0.3262 - accuracy: 0.8770 - binary_crossentropy: 0.2961 - val_loss: 0.3575 - val_accuracy: 0.8591 - val_binary_crossentropy: 0.3278
# Epoch 16/20
# 49/49 - 0s - loss: 0.3241 - accuracy: 0.8778 - binary_crossentropy: 0.2945 - val_loss: 0.3587 - val_accuracy: 0.8583 - val_binary_crossentropy: 0.3294
# Epoch 17/20
# 49/49 - 0s - loss: 0.3217 - accuracy: 0.8798 - binary_crossentropy: 0.2926 - val_loss: 0.3554 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3266
# Epoch 18/20
# 49/49 - 0s - loss: 0.3199 - accuracy: 0.8787 - binary_crossentropy: 0.2912 - val_loss: 0.3533 - val_accuracy: 0.8594 - val_binary_crossentropy: 0.3248
# Epoch 19/20
# 49/49 - 0s - loss: 0.3183 - accuracy: 0.8800 - binary_crossentropy: 0.2898 - val_loss: 0.3535 - val_accuracy: 0.8590 - val_binary_crossentropy: 0.3251
# Epoch 20/20
# 49/49 - 0s - loss: 0.3158 - accuracy: 0.8790 - binary_crossentropy: 0.2875 - val_loss: 0.3529 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3247

# %%
plot_history([('baseline', baseline_history),
              ('l2', l2_model_history)])

# %%
dpt_model = keras.models.Sequential([
    keras.layers.Dense(16, activation='relu', input_shape=(NUM_WORDS,)),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(16, activation='relu'),
    keras.layers.Dropout(0.5),
    keras.layers.Dense(1, activation='sigmoid')
])

dpt_model.compile(optimizer='adam',
                  loss='binary_crossentropy',
                  metrics=['accuracy','binary_crossentropy'])

dpt_model_history = dpt_model.fit(train_data, train_labels,
                                  epochs=20,
                                  batch_size=512,
                                  validation_data=(test_data, test_labels),
                                  verbose=2)
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6761 - accuracy: 0.5588 - binary_crossentropy: 0.6761 - val_loss: 0.5996 - val_accuracy: 0.7613 - val_binary_crossentropy: 0.5996
# Epoch 2/20
# 49/49 - 0s - loss: 0.5776 - accuracy: 0.6918 - binary_crossentropy: 0.5776 - val_loss: 0.4644 - val_accuracy: 0.8218 - val_binary_crossentropy: 0.4644
# Epoch 3/20
# 49/49 - 0s - loss: 0.4885 - accuracy: 0.7740 - binary_crossentropy: 0.4885 - val_loss: 0.3842 - val_accuracy: 0.8468 - val_binary_crossentropy: 0.3842
# Epoch 4/20
# 49/49 - 0s - loss: 0.4299 - accuracy: 0.8118 - binary_crossentropy: 0.4299 - val_loss: 0.3504 - val_accuracy: 0.8553 - val_binary_crossentropy: 0.3504
# Epoch 5/20
# 49/49 - 0s - loss: 0.4017 - accuracy: 0.8334 - binary_crossentropy: 0.4017 - val_loss: 0.3371 - val_accuracy: 0.8581 - val_binary_crossentropy: 0.3371
# Epoch 6/20
# 49/49 - 0s - loss: 0.3841 - accuracy: 0.8431 - binary_crossentropy: 0.3841 - val_loss: 0.3288 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3288
# Epoch 7/20
# 49/49 - 0s - loss: 0.3698 - accuracy: 0.8464 - binary_crossentropy: 0.3698 - val_loss: 0.3242 - val_accuracy: 0.8599 - val_binary_crossentropy: 0.3242
# Epoch 8/20
# 49/49 - 0s - loss: 0.3577 - accuracy: 0.8537 - binary_crossentropy: 0.3577 - val_loss: 0.3261 - val_accuracy: 0.8588 - val_binary_crossentropy: 0.3261
# Epoch 9/20
# 49/49 - 0s - loss: 0.3472 - accuracy: 0.8587 - binary_crossentropy: 0.3472 - val_loss: 0.3254 - val_accuracy: 0.8590 - val_binary_crossentropy: 0.3254
# Epoch 10/20
# 49/49 - 0s - loss: 0.3364 - accuracy: 0.8619 - binary_crossentropy: 0.3364 - val_loss: 0.3228 - val_accuracy: 0.8606 - val_binary_crossentropy: 0.3228
# Epoch 11/20
# 49/49 - 0s - loss: 0.3337 - accuracy: 0.8662 - binary_crossentropy: 0.3337 - val_loss: 0.3235 - val_accuracy: 0.8612 - val_binary_crossentropy: 0.3235
# Epoch 12/20
# 49/49 - 0s - loss: 0.3306 - accuracy: 0.8680 - binary_crossentropy: 0.3306 - val_loss: 0.3261 - val_accuracy: 0.8608 - val_binary_crossentropy: 0.3261
# Epoch 13/20
# 49/49 - 0s - loss: 0.3224 - accuracy: 0.8726 - binary_crossentropy: 0.3224 - val_loss: 0.3250 - val_accuracy: 0.8604 - val_binary_crossentropy: 0.3250
# Epoch 14/20
# 49/49 - 0s - loss: 0.3182 - accuracy: 0.8718 - binary_crossentropy: 0.3182 - val_loss: 0.3281 - val_accuracy: 0.8574 - val_binary_crossentropy: 0.3281
# Epoch 15/20
# 49/49 - 0s - loss: 0.3101 - accuracy: 0.8765 - binary_crossentropy: 0.3101 - val_loss: 0.3304 - val_accuracy: 0.8598 - val_binary_crossentropy: 0.3304
# Epoch 16/20
# 49/49 - 0s - loss: 0.3066 - accuracy: 0.8768 - binary_crossentropy: 0.3066 - val_loss: 0.3320 - val_accuracy: 0.8587 - val_binary_crossentropy: 0.3320
# Epoch 17/20
# 49/49 - 0s - loss: 0.3008 - accuracy: 0.8794 - binary_crossentropy: 0.3008 - val_loss: 0.3330 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3330
# Epoch 18/20
# 49/49 - 0s - loss: 0.2983 - accuracy: 0.8821 - binary_crossentropy: 0.2983 - val_loss: 0.3363 - val_accuracy: 0.8586 - val_binary_crossentropy: 0.3363
# Epoch 19/20
# 49/49 - 0s - loss: 0.2930 - accuracy: 0.8844 - binary_crossentropy: 0.2930 - val_loss: 0.3371 - val_accuracy: 0.8575 - val_binary_crossentropy: 0.3371
# Epoch 20/20
# 49/49 - 0s - loss: 0.2897 - accuracy: 0.8845 - binary_crossentropy: 0.2897 - val_loss: 0.3415 - val_accuracy: 0.8592 - val_binary_crossentropy: 0.3415

# %%
plot_history([('baseline', baseline_history),
              ('dropout', dpt_model_history)])
